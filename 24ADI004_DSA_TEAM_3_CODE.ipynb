# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevaprakash-S/24ADI204_DSV_TEAM-3/blob/main/24ADI004_DSA_TEAM_3_CODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

# %%
import kagglehub
import os
import pandas as pd

path = kagglehub.dataset_download("juhibhojani/house-price")
file = os.listdir(path)[0]

df = pd.read_csv(os.path.join(path, file))
df.head()
# Out:
# ...
# 100%|██████████| 6.61M/6.61M [00:00<00:00, 58.3MB/s]
# Extracting files...
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# ...

# %% [markdown]
# WEEK-2

# %%
print("TEAM 3 - WEEK 2")
import pandas as pd
import matplotlib.pyplot as plt
import kagglehub
import os

# Loading the dataset
path = kagglehub.dataset_download("juhibhojani/house-price")
file = os.listdir(path)[0]

df = pd.read_csv(os.path.join(path, file))

# Columns in dataset
print("COLUMN NAMES: \n")
print(df.columns)

# Inspecting structure and size
print("STRUCTURE AND SIZE: \n")
print(df.shape)
print(df.info())

# Preview the data
print("FIRST FEW ROWS: \n")
print(df.head())
# Out:
# TEAM 3 - WEEK 2
# ...
# 100%|██████████| 6.61M/6.61M [00:00<00:00, 156MB/s]
# Extracting files...
# COLUMN NAMES:
#
# Index(['Index', 'Title', 'Description', 'Amount(in rupees)',
#        'Price (in rupees)', 'location', 'Carpet Area', 'Status', 'Floor',
#        'Transaction', 'Furnishing', 'facing', 'overlooking', 'Society',
#        'Bathroom', 'Balcony', 'Car Parking', 'Ownership', 'Super Area',
#        'Dimensions', 'Plot Area'],
#       dtype='object')
# STRUCTURE AND SIZE:
#
# (187531, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        184508 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  169866 non-null  float64
# ...

# %% [markdown]
# WEEK-3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

df = pd.read_csv(
    "house_prices.csv",
    engine="python",
    on_bad_lines="skip"
)
df.dropna(axis=1, how='all', inplace=True)
print(df.info())
print(df.isnull().sum())

num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

print(df.isnull().sum())

for col in num_cols:
    plt.figure()
    plt.boxplot(df[col])
    plt.title(col)
    plt.show()

num_cols_for_outliers = [col for col in num_cols if col not in ['Dimensions', 'Plot Area']]

if not df[num_cols_for_outliers].empty:
    z_scores = np.abs(stats.zscore(df[num_cols_for_outliers]))
    outliers = z_scores > 3
    print(pd.DataFrame(outliers, columns=num_cols_for_outliers).sum())
    df_cleaned = df[(z_scores < 3).all(axis=1)]
else:
    df_cleaned = df.copy()

print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        184508 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  169866 non-null  float64
#  5   location           187531 non-null  object
#  6   Carpet Area        106858 non-null  object
#  7   Status             186916 non-null  object
#  8   Floor              180454 non-null  object
#  9   Transaction        187448 non-null  object
#  10  Furnishing         184634 non-null  object
#  11  facing             117298 non-null  object
#  12  overlooking        106095 non-null  object
#  13  Society            77853 non-null   object
#  14  Bathroom           186703 non-null  object
# ...
